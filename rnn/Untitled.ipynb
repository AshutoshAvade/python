# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding 

model = Sequential()
model.add(Embedding(vocab_size,output_dim=2,input_length=5)) #total vocab length=17,dense vector dimension[represent words through how many nos.], imput length=no of words

model.summary()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# [[[ 0.00167612  0.01362243]
#   [ 0.00186934  0.00800191]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]
#
#  [[ 0.00186934  0.00800191]
#   [ 0.00186934  0.00800191]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]
#
#  [[-0.02200717  0.04862981]
#   [-0.02200717  0.04862981]
#   [-0.03160276  0.03189783]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]
#
#  [[ 0.03918963  0.01898115]
#   [-0.00650798  0.01390872]
#   [ 0.03918963  0.01898115]
#   [ 0.00186934  0.00800191]
#   [ 0.03918963  0.01898115]]
#
#  [[ 0.03067709  0.04078842]
#   [-0.01574534 -0.04006052]
#   [ 0.01527894 -0.0216261 ]
#   [ 0.00252088 -0.03545619]
#   [-0.01127856 -0.02235637]]
#
#  [[-0.01694953  0.02410462]
#   [-0.01694953  0.02410462]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]
#
#  [[-0.03683634  0.04586578]
#   [-0.03683634  0.04586578]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]
#
#  [[ 0.01852972  0.00752914]
#   [ 0.01852972  0.00752914]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]
#
#  [[ 0.0292724  -0.03748753]
#   [ 0.04867088 -0.01912065]
#   [ 0.01527894 -0.0216261 ]
#   [ 0.00252088 -0.03545619]
#   [-0.01127856 -0.02235637]]
#
#  [[ 0.04231907  0.01292766]
#   [-0.01105913  0.04707089]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]
#   [-0.01127856 -0.02235637]]]
